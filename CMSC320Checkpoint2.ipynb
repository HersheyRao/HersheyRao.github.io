# %% [markdown]
# Here I do the necessary imports for my investigation into the apex of League of Legends ranked players :3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
import time
from scipy import stats
from datetime import datetime
import warnings

# %% [markdown]
# Here is my old api key and the base url for all api calls

# %%
# API config
API_KEY = "RGAPI-127ed7b4-2785-4ede-b208-80e21bcb03fc"
BASE_URL = {'na1': 'https://na1.api.riotgames.com'}

# %% [markdown]
# Here I define the riotAPI class that makes the API calls with the rate limits so
# that I do not get error 403'd by Riot Games.

# %%
class RiotAPI:
    def __init__(self, api_key):
        self.api_key = api_key
        self.request_count = 0
        self.last_request_time = 0
        self.requests_this_minute = 0
        self.minute_start = time.time()

    # in this method i make the api requests while handling rate limits
    def make_request(self, url, params=None):
        current_time = time.time()

        # reset timer if > 2 minutes
        if current_time - self.minute_start > 120:
            self.requests_this_minute = 0
            self.minute_start = current_time

        # max 100 requests per 2 minutes (due to riot rate limits) w/ a buffer
        if self.requests_this_minute >= 99:
            wait_time = (120 - (current_time - self.minute_start) + 5)
            if wait_time > 0:
                print(f"Limit reached. Wait {wait_time:.1f} seconds")
                time.sleep(wait_time)
                self.requests_this_minute = 0
                self.minute_start = time.time()

        # max 20 requests per second (due to riot rate limits)
        time_since_last = current_time - self.last_request_time
        if time_since_last < 0.05:
            time.sleep(0.05 - time_since_last)

        if params is None:
            params = {}
        params['api_key'] = self.api_key

        response = requests.get(url, params=params)
        self.request_count += 1
        self.requests_this_minute += 1
        self.last_request_time = time.time()

        if response.status_code == 200:
          return response.json()
        else:
          print(f"Request failed: {response.status_code}")
          return None

    #in this method i get the challenger players for the provided region (america)
    def get_challenger_players(self, region='na1'):
        url = f"{BASE_URL[region]}/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5"
        return self.make_request(url)

    # in this method i get match history via the player uid (unused; could be useful for future analysis)
    def get_match_history(self, puuid, start=0, count=20, region='americas'):
        url = f"{BASE_URL[region]}/lol/match/v5/matches/by-puuid/{puuid}/ids"
        params = {'start': start, 'count': count}
        return self.make_request(url, params)

    # in this method i get the summoner info via their player uid
    def get_summoner_by_puuid(self, puuid, region='na1'):
      url = f"{BASE_URL[region]}/lol/summoner/v4/summoners/by-puuid/{puuid}"
      return self.make_request(url)

    #in this method i get match information from the api via matchid (unused; could be useful for future analysis)
    def get_match_details(self, match_id, region='americas'):
        url = f"{BASE_URL[region]}/lol/match/v5/matches/{match_id}"
        return self.make_request(url)

# %% [markdown]
# Here I print the first player (to see what the data structure looks like), and then I load all 300 challenger players in North America. I load 300 since there are only 300 challenger slots allowed at one time. For context, incase you have never played League of Legends before, challenger is the highest rank achievable, and there are only 300 spaces allowed per region (e.g. North America, Europe, China, Korea, etc.). Then I save it into a dataframe.

# %%
riot_api = RiotAPI(API_KEY)

# Get challenger data
test_data = riot_api.get_challenger_players()

print(f"Found {len(test_data['entries'])} challenger players")

# shows the first player data structure
print(f"\nFull first player data:")
first_player = test_data['entries'][0]
print(json.dumps(first_player, indent=2))

# collect data using the keys
players_data = []

# Process all 300 challenger players
for i, player in enumerate(test_data['entries'][:300]):
    print(f"Processing player {i+1}/300")

    # Get summoner info using PUUID
    summoner_info = riot_api.get_summoner_by_puuid(player['puuid'])
    summoner_name = summoner_info.get('name', f'Player_{i+1}')
    player_data = {
        'summoner_id': player['summonerId'],
        'puuid': player['puuid'],
        'summoner_name': summoner_name,
        'tier': 'CHALLENGER',
        'rank': player.get('rank', 'I'),
        'league_points': player['leaguePoints'],
        'wins': player['wins'],
        'losses': player['losses'],
        'win_rate': round(player['wins'] / (player['wins'] + player['losses']) * 100, 2),
        'veteran': player.get('veteran', False),
        'inactive': player.get('inactive', False),
        'fresh_blood': player.get('freshBlood', False),
        'hot_streak': player.get('hotStreak', False)
    }
    players_data.append(player_data)
    print(f"Added: {summoner_name}")

# Convert to DataFrame
df_players = pd.DataFrame(players_data)

print(f"\nCollected data for {len(df_players)} players")
print(f"Total API requests made: {riot_api.request_count}")
# Out:
# Found 300 challenger players
#
# Full first player data:
# {
#   "summonerId": "Fzm9wQgN_BtyjLv9T-fLQkAtqtheOInfYpXA4aHMPSqoIUdVLCe72I2Rzw",
#   "puuid": "okWVsNjqFLZG-33IfgQVfNILcXFfGbnWVhb-eRVRlfPl3l1PYT6YJTF-npChVO8B65b41Xh5u-rP5A",
#   "leaguePoints": 2095,
#   "rank": "I",
#   "wins": 360,
#   "losses": 268,
#   "veteran": true,
#   "inactive": false,
#   "freshBlood": false,
#   "hotStreak": false
# }
# Processing player 1/300
# Added: Player_1
# Processing player 2/300
# Added: Player_2
# Processing player 3/300
# Added: Player_3
# Processing player 4/300
# Added: Player_4
# Processing player 5/300
# Added: Player_5
# Processing player 6/300
# Added: Player_6
# Processing player 7/300
# Added: Player_7
# Processing player 8/300
# Added: Player_8
# Processing player 9/300
# Added: Player_9
# Processing player 10/300
# Added: Player_10
# Processing player 11/300
# Added: Player_11
# Processing player 12/300
# Added: Player_12
# Processing player 13/300
# Added: Player_13
# Processing player 14/300
# Added: Player_14
# Processing player 15/300
# Added: Player_15
# Processing player 16/300
# Added: Player_16
# Processing player 17/300
# Added: Player_17
# Processing player 18/300
# Added: Player_18
# Processing player 19/300
# Added: Player_19
# Processing player 20/300
# Added: Player_20
# Processing player 21/300
# Added: Player_21
# Processing player 22/300
# Added: Player_22
# Processing player 23/300
# Added: Player_23
# Processing player 24/300
# Added: Player_24
# Processing player 25/300
# Added: Player_25
# Processing player 26/300
# Added: Player_26
# Processing player 27/300
# Added: Player_27
# Processing player 28/300
# Added: Player_28
# Processing player 29/300
# Added: Player_29
# Processing player 30/300
# Added: Player_30
# Processing player 31/300
# Added: Player_31
# Processing player 32/300
# Added: Player_32
# Processing player 33/300
# Added: Player_33
# Processing player 34/300
# Added: Player_34
# Processing player 35/300
# Added: Player_35
# Processing player 36/300
# Added: Player_36
# Processing player 37/300
# Added: Player_37
# Processing player 38/300
# Added: Player_38
# Processing player 39/300
# Added: Player_39
# Processing player 40/300
# Added: Player_40
# Processing player 41/300
# Added: Player_41
# Processing player 42/300
# Added: Player_42
# Processing player 43/300
# Added: Player_43
# Processing player 44/300
# Added: Player_44
# Processing player 45/300
# Added: Player_45
# Processing player 46/300
# Added: Player_46
# Processing player 47/300
# Added: Player_47
# Processing player 48/300
# Added: Player_48
# Processing player 49/300
# Added: Player_49
# Processing player 50/300
# Added: Player_50
# Processing player 51/300
# Added: Player_51
# Processing player 52/300
# Added: Player_52
# Processing player 53/300
# Added: Player_53
# Processing player 54/300
# Added: Player_54
# Processing player 55/300
# Added: Player_55
# Processing player 56/300
# Added: Player_56
# Processing player 57/300
# Added: Player_57
# Processing player 58/300
# Added: Player_58
# Processing player 59/300
# Added: Player_59
# Processing player 60/300
# Added: Player_60
# Processing player 61/300
# Added: Player_61
# Processing player 62/300
# Added: Player_62
# Processing player 63/300
# Added: Player_63
# Processing player 64/300
# Added: Player_64
# Processing player 65/300
# Added: Player_65
# Processing player 66/300
# Added: Player_66
# Processing player 67/300
# Added: Player_67
# Processing player 68/300
# Added: Player_68
# Processing player 69/300
# Added: Player_69
# Processing player 70/300
# Added: Player_70
# Processing player 71/300
# Added: Player_71
# Processing player 72/300
# Added: Player_72
# Processing player 73/300
# Added: Player_73
# Processing player 74/300
# Added: Player_74
# Processing player 75/300
# Added: Player_75
# Processing player 76/300
# Added: Player_76
# Processing player 77/300
# Added: Player_77
# Processing player 78/300
# Added: Player_78
# Processing player 79/300
# Added: Player_79
# Processing player 80/300
# Added: Player_80
# Processing player 81/300
# Added: Player_81
# Processing player 82/300
# Added: Player_82
# Processing player 83/300
# Added: Player_83
# Processing player 84/300
# Added: Player_84
# Processing player 85/300
# Added: Player_85
# Processing player 86/300
# Added: Player_86
# Processing player 87/300
# Added: Player_87
# Processing player 88/300
# Added: Player_88
# Processing player 89/300
# Added: Player_89
# Processing player 90/300
# Added: Player_90
# Processing player 91/300
# Added: Player_91
# Processing player 92/300
# Added: Player_92
# Processing player 93/300
# Added: Player_93
# Processing player 94/300
# Added: Player_94
# Processing player 95/300
# Added: Player_95
# Processing player 96/300
# Added: Player_96
# Processing player 97/300
# Added: Player_97
# Processing player 98/300
# Added: Player_98
# Processing player 99/300
# Limit reached. Wait 111.0 seconds
# Added: Player_99
# Processing player 100/300
# Added: Player_100
# Processing player 101/300
# Added: Player_101
# Processing player 102/300
# Added: Player_102
# Processing player 103/300
# Added: Player_103
# Processing player 104/300
# Added: Player_104
# Processing player 105/300
# Added: Player_105
# Processing player 106/300
# Added: Player_106
# Processing player 107/300
# Added: Player_107
# Processing player 108/300
# Added: Player_108
# Processing player 109/300
# Added: Player_109
# Processing player 110/300
# Added: Player_110
# Processing player 111/300
# Added: Player_111
# Processing player 112/300
# Added: Player_112
# Processing player 113/300
# Added: Player_113
# Processing player 114/300
# Added: Player_114
# Processing player 115/300
# Added: Player_115
# Processing player 116/300
# Added: Player_116
# Processing player 117/300
# Added: Player_117
# Processing player 118/300
# Added: Player_118
# Processing player 119/300
# Added: Player_119
# Processing player 120/300
# Added: Player_120
# Processing player 121/300
# Added: Player_121
# Processing player 122/300
# Added: Player_122
# Processing player 123/300
# Added: Player_123
# Processing player 124/300
# Added: Player_124
# Processing player 125/300
# Added: Player_125
# Processing player 126/300
# Added: Player_126
# Processing player 127/300
# Added: Player_127
# Processing player 128/300
# Added: Player_128
# Processing player 129/300
# Added: Player_129
# Processing player 130/300
# Added: Player_130
# Processing player 131/300
# Added: Player_131
# Processing player 132/300
# Added: Player_132
# Processing player 133/300
# Added: Player_133
# Processing player 134/300
# Added: Player_134
# Processing player 135/300
# Added: Player_135
# Processing player 136/300
# Added: Player_136
# Processing player 137/300
# Added: Player_137
# Processing player 138/300
# Added: Player_138
# Processing player 139/300
# Added: Player_139
# Processing player 140/300
# Added: Player_140
# Processing player 141/300
# Added: Player_141
# Processing player 142/300
# Added: Player_142
# Processing player 143/300
# Added: Player_143
# Processing player 144/300
# Added: Player_144
# Processing player 145/300
# Added: Player_145
# Processing player 146/300
# Added: Player_146
# Processing player 147/300
# Added: Player_147
# Processing player 148/300
# Added: Player_148
# Processing player 149/300
# Added: Player_149
# Processing player 150/300
# Added: Player_150
# Processing player 151/300
# Added: Player_151
# Processing player 152/300
# Added: Player_152
# Processing player 153/300
# Added: Player_153
# Processing player 154/300
# Added: Player_154
# Processing player 155/300
# Added: Player_155
# Processing player 156/300
# Added: Player_156
# Processing player 157/300
# Added: Player_157
# Processing player 158/300
# Added: Player_158
# Processing player 159/300
# Added: Player_159
# Processing player 160/300
# Added: Player_160
# Processing player 161/300
# Added: Player_161
# Processing player 162/300
# Added: Player_162
# Processing player 163/300
# Added: Player_163
# Processing player 164/300
# Added: Player_164
# Processing player 165/300
# Added: Player_165
# Processing player 166/300
# Added: Player_166
# Processing player 167/300
# Added: Player_167
# Processing player 168/300
# Added: Player_168
# Processing player 169/300
# Added: Player_169
# Processing player 170/300
# Added: Player_170
# Processing player 171/300
# Added: Player_171
# Processing player 172/300
# Added: Player_172
# Processing player 173/300
# Added: Player_173
# Processing player 174/300
# Added: Player_174
# Processing player 175/300
# Added: Player_175
# Processing player 176/300
# Added: Player_176
# Processing player 177/300
# Added: Player_177
# Processing player 178/300
# Added: Player_178
# Processing player 179/300
# Added: Player_179
# Processing player 180/300
# Added: Player_180
# Processing player 181/300
# Added: Player_181
# Processing player 182/300
# Added: Player_182
# Processing player 183/300
# Added: Player_183
# Processing player 184/300
# Added: Player_184
# Processing player 185/300
# Added: Player_185
# Processing player 186/300
# Added: Player_186
# Processing player 187/300
# Added: Player_187
# Processing player 188/300
# Added: Player_188
# Processing player 189/300
# Added: Player_189
# Processing player 190/300
# Added: Player_190
# Processing player 191/300
# Added: Player_191
# Processing player 192/300
# Added: Player_192
# Processing player 193/300
# Added: Player_193
# Processing player 194/300
# Added: Player_194
# Processing player 195/300
# Added: Player_195
# Processing player 196/300
# Added: Player_196
# Processing player 197/300
# Added: Player_197
# Processing player 198/300
# Limit reached. Wait 111.1 seconds
# Added: Player_198
# Processing player 199/300
# Added: Player_199
# Processing player 200/300
# Added: Player_200
# Processing player 201/300
# Added: Player_201
# Processing player 202/300
# Added: Player_202
# Processing player 203/300
# Added: Player_203
# Processing player 204/300
# Added: Player_204
# Processing player 205/300
# Added: Player_205
# Processing player 206/300
# Added: Player_206
# Processing player 207/300
# Added: Player_207
# Processing player 208/300
# Added: Player_208
# Processing player 209/300
# Added: Player_209
# Processing player 210/300
# Added: Player_210
# Processing player 211/300
# Added: Player_211
# Processing player 212/300
# Added: Player_212
# Processing player 213/300
# Added: Player_213
# Processing player 214/300
# Added: Player_214
# Processing player 215/300
# Added: Player_215
# Processing player 216/300
# Added: Player_216
# Processing player 217/300
# Added: Player_217
# Processing player 218/300
# Added: Player_218
# Processing player 219/300
# Added: Player_219
# Processing player 220/300
# Added: Player_220
# Processing player 221/300
# Added: Player_221
# Processing player 222/300
# Added: Player_222
# Processing player 223/300
# Added: Player_223
# Processing player 224/300
# Added: Player_224
# Processing player 225/300
# Added: Player_225
# Processing player 226/300
# Added: Player_226
# Processing player 227/300
# Added: Player_227
# Processing player 228/300
# Added: Player_228
# Processing player 229/300
# Added: Player_229
# Processing player 230/300
# Added: Player_230
# Processing player 231/300
# Added: Player_231
# Processing player 232/300
# Added: Player_232
# Processing player 233/300
# Added: Player_233
# Processing player 234/300
# Added: Player_234
# Processing player 235/300
# Added: Player_235
# Processing player 236/300
# Added: Player_236
# Processing player 237/300
# Added: Player_237
# Processing player 238/300
# Added: Player_238
# Processing player 239/300
# Added: Player_239
# Processing player 240/300
# Added: Player_240
# Processing player 241/300
# Added: Player_241
# Processing player 242/300
# Added: Player_242
# Processing player 243/300
# Added: Player_243
# Processing player 244/300
# Added: Player_244
# Processing player 245/300
# Added: Player_245
# Processing player 246/300
# Added: Player_246
# Processing player 247/300
# Added: Player_247
# Processing player 248/300
# Added: Player_248
# Processing player 249/300
# Added: Player_249
# Processing player 250/300
# Added: Player_250
# Processing player 251/300
# Added: Player_251
# Processing player 252/300
# Added: Player_252
# Processing player 253/300
# Added: Player_253
# Processing player 254/300
# Added: Player_254
# Processing player 255/300
# Added: Player_255
# Processing player 256/300
# Added: Player_256
# Processing player 257/300
# Added: Player_257
# Processing player 258/300
# Added: Player_258
# Processing player 259/300
# Added: Player_259
# Processing player 260/300
# Added: Player_260
# Processing player 261/300
# Added: Player_261
# Processing player 262/300
# Added: Player_262
# Processing player 263/300
# Added: Player_263
# Processing player 264/300
# Added: Player_264
# Processing player 265/300
# Added: Player_265
# Processing player 266/300
# Added: Player_266
# Processing player 267/300
# Added: Player_267
# Processing player 268/300
# Added: Player_268
# Processing player 269/300
# Added: Player_269
# Processing player 270/300
# Added: Player_270
# Processing player 271/300
# Added: Player_271
# Processing player 272/300
# Added: Player_272
# Processing player 273/300
# Added: Player_273
# Processing player 274/300
# Added: Player_274
# Processing player 275/300
# Added: Player_275
# Processing player 276/300
# Added: Player_276
# Processing player 277/300
# Added: Player_277
# Processing player 278/300
# Added: Player_278
# Processing player 279/300
# Added: Player_279
# Processing player 280/300
# Added: Player_280
# Processing player 281/300
# Added: Player_281
# Processing player 282/300
# Added: Player_282
# Processing player 283/300
# Added: Player_283
# Processing player 284/300
# Added: Player_284
# Processing player 285/300
# Added: Player_285
# Processing player 286/300
# Added: Player_286
# Processing player 287/300
# Added: Player_287
# Processing player 288/300
# Added: Player_288
# Processing player 289/300
# Added: Player_289
# Processing player 290/300
# Added: Player_290
# Processing player 291/300
# Added: Player_291
# Processing player 292/300
# Added: Player_292
# Processing player 293/300
# Added: Player_293
# Processing player 294/300
# Added: Player_294
# Processing player 295/300
# Added: Player_295
# Processing player 296/300
# Added: Player_296
# Processing player 297/300
# Limit reached. Wait 111.2 seconds
# Added: Player_297
# Processing player 298/300
# Added: Player_298
# Processing player 299/300
# Added: Player_299
# Processing player 300/300
# Added: Player_300
#
# Collected data for 300 players
# Total API requests made: 301

# %% [markdown]
# # **First Conclusion:**
#
# In this section, in order to begin analyzing the dataset, I first calculate the basic descriptive statistics of the dataset. The findings are that the average win rate among the 300 challengers in North America is 55.7%, with a standard deviation of 3.5%. The range in LP was from 795 to 2095, which shows a massive spread in how much league points a challenger player can have. The mean LP is 1095, so it is possible that the values around 2000 are outliers in the dataset. In the dataset, it is also true that the mean number of games is 452 with a standard deviation of 207, so the 'average' number of games played so far this season by a challenger north american player is 452, but the standard deviation is quite large at 207 games, so there is a lot of variance in that dataset. The minimum and maximum number of games played is 131 and 1256 respectively.
#
# In addition, both the win rate histogram and the league points histogram are right skewed, which indicates that only a few players even in challenger have a win rate higher than 55, and most players in challenger have a win rate around the mean, with a few vastly above it. This indicates that a small group of players with extremely high LP and win rate values is pulling the mean of each histogram to the right. Similarly, below is also a box and whisker plot showing the win rates and LP data, with the LP scaled down by 2000 to fit on the same plot. Lastly, there is a scatter plot that shows total games played vs win rate, with the color being mapped to the LP. At first glance, this plot shows no strong linear correlation between games played and LP, and high LP (dark purple) seems to be more correlated with high win rate and more games played, which suggests that in order to hit challenger, one must either win the vast majority of the games that they play or one must consistently win a majority of the games played and simply play a lot of games as well.

# %%
# Calculate stats for each challenger player
df_players['total_games'] = df_players['wins'] + df_players['losses']
df_players['win_rate'] = df_players['wins'] / df_players['total_games']
df_players['games_per_lp'] = df_players['total_games'] / df_players['league_points']

# show df_players info:
print(f"Dataset shape: {df_players.shape}")
print(f"Columns: {list(df_players.columns)}")
print("dataset:")
print(df_players)
print("\nSummary stats:")
print(df_players.describe())

# Analysis:
# Method 1: Describing the players
print("\n1. Descriptive statistics:")
print(f"Average win rate: {df_players['win_rate'].mean():.3f} ± {df_players['win_rate'].std():.3f}")
print(f"League points range: {df_players['league_points'].min()} - {df_players['league_points'].max()}")
print(f"Most games played: {df_players['total_games'].max()}")

# first (of many) beautiful plot: Distributions of WR and LP
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle('Challenger Player Statistics Distribution', fontsize=16, fontweight='bold')

# Win rate distribution (tried to make each bin ~1% wr)
axes[0,0].hist(df_players['win_rate'], bins=23, edgecolor = 'black')
axes[0,0].axvline(df_players['win_rate'].mean(), color='red', linestyle='-', label=f'Mean: {df_players["win_rate"].mean():.3f}')
axes[0,0].set_title('Win Rate Distribution')
axes[0,0].set_xlabel('Win Rate')
axes[0,0].set_ylabel('Frequency')
axes[0,0].legend()

# League points distribution (each bin ~100LP)
axes[0,1].hist(df_players['league_points'], bins=15, color='#008000', edgecolor='black')
axes[0,1].axvline(df_players['league_points'].mean(), color='red', linestyle='-', label=f'Mean: {df_players["league_points"].mean():.0f}')
axes[0,1].set_title('League Points Distribution')
axes[0,1].set_xlabel('League Points')
axes[0,1].set_ylabel('Frequency')
axes[0,1].legend()

# Box plots (with LP scaled down by 2k so they fit in the same plot)
box_data = [df_players['win_rate'], df_players['league_points']/2000]
axes[1,0].boxplot(box_data, labels=['Win Rate', 'LP (divided by 2000)'])
axes[1,0].set_title('Statistical Summary')
axes[1,0].set_ylabel('Value')

# Total games vs win rate (chose plasma for colormapping since it looks nice)
scatter = axes[1,1].scatter(df_players['total_games'], df_players['win_rate'],
                           c=df_players['league_points'], cmap='plasma', alpha=0.75)
axes[1,1].set_title('Total Games vs Win Rate')
axes[1,1].set_xlabel('Total Games Played')
axes[1,1].set_ylabel('Win Rate')
plt.colorbar(scatter, ax=axes[1,1], label='League Points')
plt.tight_layout(pad = 1.0)
plt.show()
# Out:
# Dataset shape: (300, 15)
# Columns: ['summoner_id', 'puuid', 'summoner_name', 'tier', 'rank', 'league_points', 'wins', 'losses', 'win_rate', 'veteran', 'inactive', 'fresh_blood', 'hot_streak', 'total_games', 'games_per_lp']
# dataset:
#                                            summoner_id  \
# 0    Fzm9wQgN_BtyjLv9T-fLQkAtqtheOInfYpXA4aHMPSqoIU...
# 1     6h1d5-wKsFf-F1DSq9x7kDRfL21j4enEO3kFEpC1tKCxugZZ
# 2    w9pI1BrSuRqxHu5cm59Uif7tC7upJdTS4aFkpCHkwOSTV_...
# 3      24wkpLf5yccPDzHbkHjgjjWY1sUPrB1hz23Nub6tebLlnqc
# 4     oMl-C2B4RYiaBaegodVst9sLj2KIaK-uuWkBLQRl2KTMr44e
# ..                                                 ...
# 295    8-GxOUb6s_GKkTWJDxst0RuLmZ_3r0rYaKxQc0-dCFBDb5Y
# 296  dErq1CIde52Zk7dSPNC33fqy-P82SXKVC93nJgC-QKIR9B...
# 297    Z54MAGnLd252z_AHWGpEYWWXkT7md9gVan73Q4TXzJAEv_U
# 298   yAyhqDCApTSqyYQAyA-ovxqAiYEbAX67vEjmKlfF54fRi7Hi
# 299  KwUx6IUelKlgOYILMrGkG61HHSEDaMgjH8q2iNgAscnmX-...
#
#                                                  puuid summoner_name  \
# 0    okWVsNjqFLZG-33IfgQVfNILcXFfGbnWVhb-eRVRlfPl3l...      Player_1
# 1    rzW2Enb6U6SQl0sL6wUG0bw7THvYtxYVaN_tKOrpC6LRNN...      Player_2
# 2    av40uCUK2Q27hs5L1ZaHkZ0gnMF7wdFWjpfHVvOADX9X71...      Player_3
# 3    vp8Sk3j6Q8b4rH1bdIR4Y-CfzvBin-BsyiYY9hPHUvjQ17...      Player_4
# 4    oRonNGBYirJD19MAM4h1-0d9sDtAgpbBCzT2KAqhRHl52A...      Player_5
# ..                                                 ...           ...
# 295  5v2NMguYOuWne5HW8eHv1TTzZWAnRc-51J0iMO6e58DRaZ...    Player_296
# 296  LW8tc4475qGuJj9Pt0bfgVzcReJ--Q-S3O-9e1lPkA-JNy...    Player_297
# 297  Bp3VKTPHrZWCZr2ZhcGKjqhvbdEtWTR3rAB1UULypSdYbR...    Player_298
# 298  Er-uegVr09UUzfa1jpdWT0-OEQT9Pb4uhBIWJbRIQW6ndv...    Player_299
# 299  q3pDafaD55Atdh1Ayd1dpiOvrwlQakyDQ9L99DUZz1jZRM...    Player_300
#
#            tier rank  league_points  wins  losses  win_rate  veteran  \
# 0    CHALLENGER    I           2095   360     268  0.573248     True
# 1    CHALLENGER    I           2033   304     208  0.593750     True
# 2    CHALLENGER    I           1938   370     260  0.587302     True
# 3    CHALLENGER    I           1762   250     183  0.577367     True
# 4    CHALLENGER    I           1754   297     233  0.560377     True
# ..          ...  ...            ...   ...     ...       ...      ...
# 295  CHALLENGER    I            852   468     450  0.509804    False
# 296  CHALLENGER    I            839   232     194  0.544601    False
# 297  CHALLENGER    I            833   363     340  0.516358     True
# 298  CHALLENGER    I            828   138     102  0.575000    False
# 299  CHALLENGER    I            795   257     222  0.536534    False
#
#      inactive  fresh_blood  hot_streak  total_games  games_per_lp
# 0       False        False       False          628      0.299761
# 1       False        False        True          512      0.251845
# 2       False        False       False          630      0.325077
# 3       False        False       False          433      0.245743
# 4       False        False       False          530      0.302166
# ..        ...          ...         ...          ...           ...
# 295     False         True        True          918      1.077465
# 296     False         True       False          426      0.507747
# 297     False        False        True          703      0.843938
# 298     False         True       False          240      0.289855
# 299     False         True       False          479      0.602516
#
# [300 rows x 15 columns]
#
# Summary stats:
#        league_points        wins      losses    win_rate  total_games  \
# count     300.000000  300.000000  300.000000  300.000000   300.000000
# mean     1059.000000  247.156667  205.236667    0.557404   452.393333
# std       215.002357  103.198734  104.530999    0.035057   207.187566
# min       795.000000   83.000000   45.000000    0.509804   131.000000
# 25%       906.000000  168.500000  128.000000    0.532056   299.500000
# 50%       993.000000  231.000000  187.500000    0.549166   419.000000
# 75%      1142.250000  304.000000  265.000000    0.572861   573.000000
# max      2095.000000  651.000000  605.000000    0.733728  1256.000000
#
#        games_per_lp
# count    300.000000
# mean       0.439687
# std        0.218113
# min        0.117174
# 25%        0.286356
# 50%        0.373639
# 75%        0.552863
# max        1.395556
#
# 1. Descriptive statistics:
# Average win rate: 0.557 ± 0.035
# League points range: 795 - 2095
# Most games played: 1256
# /tmp/ipython-input-168-3666423388.py:43: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1,0].boxplot(box_data, labels=['Win Rate', 'LP (divided by 2000)'])

# %% [markdown]
# # **Conclusion 2:**
#
# In order to further explore the relationship between the numerical variables listed above, I computed and display here a Pearson correlation matrix using League Points, wins, losses, total games played, and win rate for the same challenger players in North America. I then visualise this using reverse inferno coloring, so a darker color for the box means there is a stronger correlation between the two. As you can see, the diagonal of the box (top left to bottom right) all has a correlation coefficient of 1, which is expected as every variable should be strongly correlated with itself. In addition, the other observed strong correlations are between total games and wins (~0.997), and total games and losses (0.997). This is to be expected since wins as well as losses are a component of total games played. Losses are also strongly correlated with wins (0.9896) which makes sense since as a person wins more if their win rate is around 50%, which it will be due to matchmaking, their loss ratio will also trend towards 50%.
#
# **More interestingly, League points are weakly positively correlated with win rate, total games, losses, and wins** (0.1550, 0.0525, 0.0113, and 0.0939 respectively). LP and win rate have the strongest correlation coefficient out of these, which makes sense since a higher win rate would lead to more LP in a lot of cases. This suggests that LP is influenced by factors other than simply wins, losses, total wins, and surprisingly even win rate. Some other important factors that influence LP could be how long someone has been playing the game, the lp of their opponents in each game, and if they are on a hot streak.
#
# **Lastly, there is a strong negative correlation between total games played and win rate(-0.692)**. This correlation has a p-value of ~0.0000, which is most definitely lower than the critical value alpha = 0.05. This indicates that it is not simply by pure chance, and this also points towards the fact that as someone plays more and more games, their win rate would trend down, likely because of the fact that the matchmaking system attempts to put equal skilled players in the same game, so as someone plays more and more games their win rate would equalize to 50% over time, even for challenger players. This suggests that once again, like our first conclusion, the two main ways that people typically get to challenger are either to grind out many games at a slightly lower win rate (still above 50% though) or to simply have a high win rate with a lower number of games played.

# %%
# Method 2: analysing for correlation
print("\n2. correlation analysis:")
numeric_cols = ['league_points', 'wins', 'losses', 'total_games', 'win_rate']
correlation_matrix = df_players[numeric_cols].corr()

# second dazzling plot: Correlation Heatmap
plt.figure(figsize=(12, 10))

# not exactly relevant but reverse inferno looks nice on the colormap here
sns.heatmap(correlation_matrix,annot=True, cmap='inferno_r',
            square=True, linewidths=0.5, fmt='.4f')

plt.title('Challenger Player Correlation Matrix',fontweight='bold', pad=1.0)
plt.tight_layout()
plt.show()

# show p value for games-win rate correlation
corr_games_wr, p_games_wr = stats.pearsonr(df_players['total_games'], df_players['win_rate'])
print(f"Games-Win Rate correlation: r={corr_games_wr:.3f}, p={p_games_wr:.4f}")
# Out:
# 2. correlation analysis:
# Games-Win Rate correlation: r=-0.692, p=0.0000

# %% [markdown]
# # **Conclusion 3: **
#
# In order to test the data further, I conducted two hypothesis tests involving the win rates and the LP of challenger players in North America. **First, I tested the hypothesis that: "win rate is strongly correlated with league points."** Via Pearson correlation, I found a coefficient of 0.1550 and a p-value of 0.0071, which is lower than the critical value of alpha=0.05. This means that it was not due to chance, and we can accept that hypothesis that there is a statistically significant correlation between win rate and league points. However, while the correlation is statistically significant, the residual plot shows that win rate by itself is a weak predictor of LP. This support our findings and the earlier two conclusions.
#
# In addition, I also tested the hypothesis that: "veteran players will have a different win rate than non-veteran players." I compared the mean win rates of veteran and non-veteran players out of the 300 North American Challengers using the provided tag from the Riot API and a two sample t test. "Veteran" in the Riot API context means an account that has played 100 games in the specified division (challenger in this case). The finding were that veteran players had a mean win rate of 55.2% and non-veteran players had a mean win rate of 56.1%. The p-value for this test was 0.0172, which is lower than the critical value of 0.05, which means we can accept the hypothesis that veteran players will have a different win rate than non-veteran players. Suprisingly, the mean win rate for non-veteran players was higher as opposed to veteran players. This suggests that newer players in challenger (<100 games played) have a higher win rate than players with over 100 games in challenger. This is likely because veteran players would have played more games in challenger, and since there is higher competition in challenger as the skill level is the highest there compared to all other ranks, thus their win rate would drop as a result of harder matches. Another possible explanation is that in order for a player who is not challenger to get challenger, they must first establish a high win rate in order to climb out of grandmaster in the first place. Thus, it could also be selection bias.

# %%
# Method 3: Hypothesis testing
print(" First Hypothesis: Win rate is strongly correlated with league points")

# calculate and print pearson correlation coefficient
corr_coeff, p_value = stats.pearsonr(df_players['win_rate'], df_players['league_points'])
print(f"Pearson correlation coefficient: {corr_coeff:.4f}")
print(f"P-value: {p_value:.4f}")

# compare the p value to alpha = 0.05 (for statistical significance)
if p_value < 0.05:
    print(f"Result: statistically significant correlation was found ({p_value: .4f} < 0.05)")
else:
    print(f"Result: no statistically significant correlation was found ({p_value: .4f} >= 0.05)")

# second hypothesis test: Compare veteran vs non-veteran players and check if its statistically significant
print("Hypothesis for second test: veterans will have a different win rate from non-veteran players (in challenger)")
veteran_wr = df_players[df_players['veteran'] == True]['win_rate']
non_veteran_wr = df_players[df_players['veteran'] == False]['win_rate']
t_stat, t_p_value = stats.ttest_ind(veteran_wr, non_veteran_wr)
print(f"\nVeteran vs Non-veteran win rate comparison:")
print(f"Veteran mean win rate: {veteran_wr.mean():.3f}")
print(f"Non-veteran mean win rate: {non_veteran_wr.mean():.3f}")
print(f"T-test p-value: {t_p_value:.4f}")
if t_p_value < 0.05:
    print(f"Result: statistically significant correlation was found ({t_p_value: .4f} < 0.05)")
else:
    print(f"Result: no statistically significant correlation was found ({t_p_value: .4f} >= 0.05)")

# third stunning plot: linear regression and residuals
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Scatter plot WR vs LP w/ regression line
axes[0].scatter(df_players['win_rate'], df_players['league_points'], alpha=0.75)
z = np.polyfit(df_players['win_rate'], df_players['league_points'], 1)
p = np.poly1d(z)
axes[0].plot(df_players['win_rate'], p(df_players['win_rate']), "r-")
axes[0].set_xlabel('Win Rate')
axes[0].set_ylabel('League Points')
axes[0].set_title('Win Rate vs League Points\n(w/ regression line)')
axes[0].grid(True, alpha=0.25)

# Add label box in top right corner
axes[0].text(0.05, 0.95, f'r = {corr_coeff:.3f}\np = {p_value:.3f}',
             transform=axes[0].transAxes,bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

# create the residual plot (actual vals - predicted from regression line)
predicted = p(df_players['win_rate'])
residuals = df_players['league_points'] - predicted
axes[1].scatter(predicted, residuals, alpha=0.75, color='#008000')
axes[1].axhline(y=0, color='red', linestyle='--')
axes[1].set_xlabel('Predicted League Points')
axes[1].set_ylabel('Residuals')
axes[1].set_title('Residual Plot')
axes[1].grid(True, alpha=0.25)

plt.tight_layout()
plt.show()

# save data to a .csv file for future use
df_players.to_csv('challenger_players_data.csv')
print("Data saved to challenger_players_data.csv")
# Out:
#  First Hypothesis: Win rate is strongly correlated with league points
# Pearson correlation coefficient: 0.1550
# P-value: 0.0071
# Result: statistically significant correlation was found ( 0.0071 < 0.05)
# Hypothesis for second test: veterans will have a different win rate from non-veteran players (in challenger)
#
# Veteran vs Non-veteran win rate comparison:
# Veteran mean win rate: 0.552
# Non-veteran mean win rate: 0.561
# T-test p-value: 0.0172
# Result: statistically significant correlation was found ( 0.0172 < 0.05)
# Data saved to challenger_players_data.csv
